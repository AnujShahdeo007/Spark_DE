# %%
from pyspark.sql import SparkSession
spark=SparkSession.builder \
    .appName("pyspark DF") \
    .master("local[*]") \
    .getOrCreate()
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/02/25 16:44:19 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
data=[("Gaurav",25.0),("Rahul",30.0),("Neha",56.0)]
df=spark.createDataFrame(data,["Name","age"])
df.show()
# Out:
# +------+----+
# |  Name| age|
# +------+----+
# |Gaurav|25.0|
# | Rahul|30.0|
# |  Neha|56.0|
# +------+----+

# %%
df.printSchema()
# Out:
# root
#  |-- Name: string (nullable = true)
#  |-- age: double (nullable = true)

# %% [markdown]
# # Explicit Schema

# %%
from pyspark.sql.types import StructType,StructField,StringType,IntegerType
# pyspark.sql.types - Spark data type definition module 
# StructType - a full schema object (table structure)
# StructField - One column definition 
data=[
        ("101","gaurav",30),
        ("102","Rahul",40)
     ]

schema= StructType([
    StructField("id",StringType(),True),
    StructField("Name",StringType(),False),
    StructField("Age",IntegerType(),True),

])

df=spark.createDataFrame(data,schema)

# %%
df.printSchema()
# Out:
# root
#  |-- id: string (nullable = true)
#  |-- Name: string (nullable = false)
#  |-- Age: integer (nullable = true)

# %%
data= [
        {"Name":"gaurav","age":30},
        {"Name":"rahul","age":40}
    ]

df_dict=spark.createDataFrame(data)

# %%
df_dict.show()
# Out:
# +------+---+
# |  Name|age|
# +------+---+
# |gaurav| 30|
# | rahul| 40|
# +------+---+

# %%
import pandas as pd 
pdf=pd.DataFrame({
    "Name":["Gaurav","Rahul"],
    "Age":[30,40]
})

# %%
df_pand=spark.createDataFrame(pdf)

# %%
df_pand.show()
# Out:
# +------+---+
# |  Name|Age|
# +------+---+
# |Gaurav| 30|
# | Rahul| 40|
# +------+---+
