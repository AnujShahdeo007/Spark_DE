# %% [markdown]
# Easy:
#
# 1.  Count vowles in a string
#     input: "datascience"
#     output: 5
#
# 2. "Data enginerring is fun" ---> "fun is enginerring Data"
#    "I love Python"          ----> "Python love I"
#
# 3. Remove duplicate but keep the original order
#     [1,2,1,3,2] ----> [1,2,3]
#     ["a","b","a","c","b"]. ------> ["a","b","c"]
#     Note: Order Matters
#
# 4. First non repeating character in a string
#     "aabbcdd" ---> "c"
#     "xxyyzz"  --->  None
#     "datascience" ---> "d"
#
#
# 5. Check if two strings are anagrams
#
# Input: "listen", "silent"
# Output: True
#
# 6. Palindrome check (ignore case & spaces)
#
# Input: "A man a plan a canal panama"
# Output: True
#
# 7. Second largest number
#
# Input: [10, 5, 20, 8]
# Output: 10
#
# 8. Character frequency
#
# Input: "datascience"
# Output:
#
# {'d':1,'a':2,'t':1,'s':1,'c':2,'i':1,'e':2,'n':1}
#
# 9. Move zeros to end
#
# Input: [1, 0, 3, 0, 5]
# Output: [1, 3, 5, 0, 0]
#
# 10. um of digits
#
# Input: 3456
# Output: 18
#
# MEDIUM
# ------
#
# 1. Top-K frequent elements
#
# Input: [1,1,1,2,2,3], k=2
# Output: [1,2]
#
# 2. Longest substring without repeating characters
#
# Input: "abcabcbb"
# Output: 3
#
# 3. Merge overlapping intervals
#
# Input: [(1,3),(2,6),(8,10),(9,12)]
# Output: [(1,6),(8,12)]
#
# 4. Two-sum (indices)
#
# Input: nums=[2,7,11,15], target=9
# Output: [0,1]
#
# 5. Group-by sum (SQL style)
#
# Input: [("books",200),("toys",100),("books",150)]
# Output: {"books":350,"toys":100}
#
# 6. Find missing numbers (1 to n)
#
# Input: [1,2,4,6], n=6
# Output: [3,5]
#
# 7. Rotate array by k
#
# Input: [1,2,3,4,5], k=2
# Output: [4,5,1,2,3]
#
# 8. Valid parentheses
#
# Input: "({[]})"
# Output: True
#
# 9. Product of array except self
#
# Input: [1,2,3,4]
# Output: [24,12,8,6]
#
# 10. Find duplicate records by key
#
# Input:
#
# [
#  {"id":1,"name":"A"},
#  {"id":2,"name":"B"},
#  {"id":1,"name":"C"}
# ]
#
#
# Output:
#
# [{"id":1,"name":"A"},{"id":1,"name":"C"}]
#
# HARD
# ----
#
# 1. Minimum window substring
#
# Input: s="ADOBECODEBANC", t="ABC"
# Output: "BANC"
#
# 2. LRU Cache (capacity=2)
#
# Input:
#
# put(1,1)
# put(2,2)
# get(1)
# put(3,3)
#
#
# Output:
#
# 1
# -1
#
# 3. Median from data stream
#
# Input: [5, 15, 1, 3]
# Output: [5,10,5,4]
#
# 4. Longest consecutive sequence
#
# Input: [100,4,200,1,3,2]
# Output: 4
#
# 5. Trapping rain water
#
# Input: [0,1,0,2,1,0,1,3,2,1,2,1]
# Output: 6
#
# 6. Largest rectangle in histogram
#
# Input: [2,1,5,6,2,3]
# Output: 10
#
# 7. Detect cycle in linked list
#
# Input: 1 → 2 → 3 → 4 → 2
# Output: True
#
# 8. Serialize & deserialize nested JSON
#
# Input: {"a":1,"b":{"c":2}}
# Output: Same structure after deserialization
#
# 9. Kth smallest element in sorted matrix
#
# Input:
#
# matrix = [
#  [1,5,9],
#  [10,11,13],
#  [12,13,15]
# ]
# k = 8
#
#
# Output: 13
#
# 10. Deduplicate streaming events (latest by timestamp)
#
# Input:
#
# [
#  {"id":1,"ts":100},
#  {"id":1,"ts":105},
#  {"id":2,"ts":90}
# ]
#
#
# Output:
#
# [
#  {"id":1,"ts":105},
#  {"id":2,"ts":90}
# ]

# %%
# count=0
a= "DataScience"
vowels=set("aeiou")
# b="aeiou"
# for count in a:
#     print(count)
# #     if count in b:
# #         count +=1
# # print(count)
# count=0
# for ch in a.lower():
#     if ch in vowels:
#         count +=1
# print(count)
count=sum(1 for ch in a.lower() if ch in vowels)
print(count)
# Out:
# 5

# %%
hash('a')
# Out:
# 5393558122681327649

# %%
hash('e')
# Out:
# -2748588969583100435

# %%
hash('a')
# Out:
# 5393558122681327649

# %%
#2. 
s="data enginerring is fun"
words=s.split()
print(words)
rev_words=words[::-1]
print(rev_words)
result=" ".join(rev_words)
print(result)
# Out:
# ['data', 'enginerring', 'is', 'fun']
# ['fun', 'is', 'enginerring', 'data']
# fun is enginerring data

# %%
#3. 
#arr=[1,2,1,3,2]
arr=["a","b","a","c","b"]
seen=set()
result=[]
for x in arr:
    if x not in seen:
        seen.add(x)
        result.append(x)
print(result)
# Out:
# ['a', 'b', 'c']

# %%
from collections import Counter
s="aabbcddc"
freq=Counter(s)
print(freq)
result=None
for ch in s:
    if freq[ch]==1:
        result=ch
        break
print(result)
# Out:
# Counter({'a': 2, 'b': 2, 'c': 2, 'd': 2})
# None
